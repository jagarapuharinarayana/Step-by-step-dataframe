# %%
# !python --version
# Out:
# Python 3.10.8

# %%
import pandas as pd
mydataset={"cars":["BMW","zeebra","FIAT","FORD"],
"BIKES":["SPLENDOR","GLAMOUR","ROYAL ENFIELD","12"]}

# %%
mydataset
# Out:
# {'cars': ['BMW', 'zeebra', 'FIAT', 'FORD'],
#  'BIKES': ['SPLENDOR', 'GLAMOUR', 'ROYAL ENFIELD', '12']}

# %%
df=pd.DataFrame(mydataset)

# %%
df
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df['cars']
# Out:
# 0       BMW
# 1    zeebra
# 2      FIAT
# 3      FORD
# Name: cars, dtype: object

# %%
df['BIKES']
# Out:
# 0         SPLENDOR
# 1          GLAMOUR
# 2    ROYAL ENFIELD
# 3               12
# Name: BIKES, dtype: object

# %%
df
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df.loc[0]
# Out:
# cars          BMW
# BIKES    SPLENDOR
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# cars          BMW
# BIKES    SPLENDOR
# Name: 0, dtype: object

# %%
df.head()
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df.shape
# Out:
# (4, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cars    4 non-null      object
#  1   BIKES   4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
df.dtypes
# Out:
# cars     object
# BIKES    object
# dtype: object

# %%
df.dtypes
# Out:
# cars     object
# BIKES    object
# dtype: object

# %%
df['cars'] = df['cars'].astype('str')

# %%
df['cars']
# Out:
# 0       BMW
# 1    zeebra
# 2      FIAT
# 3      FORD
# Name: cars, dtype: object

# %%
df.columns.values
# Out:
# array(['cars', 'BIKES'], dtype=object)

# %%
df.describe().transpose
# Out:
# <bound method DataFrame.transpose of        cars     BIKES
# count     4         4
# unique    4         4
# top     BMW  SPLENDOR
# freq      1         1>

# %%
orderedcars=df['cars'].sort_values(ascending=True)

# %%
orderedcars
# Out:
# 0       BMW
# 2      FIAT
# 3      FORD
# 1    zeebra
# Name: cars, dtype: object

# %%
type(orderedcars)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df['BIKES'].unique()
# Out:
# array(['SPLENDOR', 'GLAMOUR', 'ROYAL ENFIELD', '12'], dtype=object)

# %%
df.sort_values(by=['BIKES'])
# Out:
#      cars          BIKES
# 3    FORD             12
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 0     BMW       SPLENDOR

# %%
df.loc[2]
# Out:
# cars              FIAT
# BIKES    ROYAL ENFIELD
# Name: 2, dtype: object

# %%
df.T
# Out:
#               0        1              2     3
# cars        BMW   zeebra           FIAT  FORD
# BIKES  SPLENDOR  GLAMOUR  ROYAL ENFIELD    12

# %%
df
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df.loc[2:-1]
# Out:
# Empty DataFrame
# Columns: [cars, BIKES]
# Index: []

# %%
df.loc[2]
# Out:
# cars              FIAT
# BIKES    ROYAL ENFIELD
# Name: 2, dtype: object

# %%
df
# Out:
#      cars          BIKES
# 0     BMW       SPLENDOR
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD
# 3    FORD             12

# %%
df.loc[1:2]
# Out:
#      cars          BIKES
# 1  zeebra        GLAMOUR
# 2    FIAT  ROYAL ENFIELD

# %%
import os

# %%
pwd
# Out:
# 'D:\\'

# %%
import pandas as pd

# %%
df=pd.read_excel(r"D:\2020 students list.xlsx")

# %%
# Out:
# <bound method Series.unique of 0      A
# 1      A
# 2      A
# 3      A
# 4      A
#       ..
# 730    L
# 731    L
# 732    L
# 733    L
# 734    L
# Name: Section, Length: 735, dtype: object>

# %%
df=df.sort_values(by=['Section'])

# %%
df['Section']=="A"
# Out:
# 0       True
# 36      True
# 37      True
# 38      True
# 39      True
#        ...
# 701    False
# 702    False
# 703    False
# 705    False
# 734    False
# Name: Section, Length: 735, dtype: bool

# %%
for i in df['Section']:
   
    print(df1)
# Out:
#     S.No   Register No.                            Student Name  Program  \
# 0      1  AP20110010001                      UPPULURI VAISHNAVI  B.Tech.
# 36    37  AP20110010042                      VISHAL KUMAR SINGH  B.Tech.
# 37    38  AP20110010043                            JAYESH JETHY  B.Tech.
# 38    39  AP20110010044           KOTHAPALLI VENKATA SAI HARSHA  B.Tech.
# 39    40  AP20110010045   VEDANABHATLA V M P SURYA SAI HARSHITH  B.Tech.
# ..   ...            ...                                     ...      ...
# 22    23  AP20110010025                 CHINNAM GOUTHAM NISCHAY  B.Tech.
# 21    22  AP20110010024  CHORAPALLI VEERA VENKATA SATYANARAYANA  B.Tech.
# 20    21  AP20110010023        NARAHARI MANASA SIRI RAGHAVENDRA  B.Tech.
# 19    20  AP20110010022                       SATHVIKA VEGIRAJU  B.Tech.
# 24    25  AP20110010028                       THADIMARRI SAMEER  B.Tech.
#
#                               Branch  Batch Section  \
# ...

# %%
 df1 = df[df['Section']=="A"]

# %%
print(df1)
# Out:
#     S.No   Register No.                            Student Name  Program  \
# 0      1  AP20110010001                      UPPULURI VAISHNAVI  B.Tech.
# 36    37  AP20110010042                      VISHAL KUMAR SINGH  B.Tech.
# 37    38  AP20110010043                            JAYESH JETHY  B.Tech.
# 38    39  AP20110010044           KOTHAPALLI VENKATA SAI HARSHA  B.Tech.
# 39    40  AP20110010045   VEDANABHATLA V M P SURYA SAI HARSHITH  B.Tech.
# ..   ...            ...                                     ...      ...
# 22    23  AP20110010025                 CHINNAM GOUTHAM NISCHAY  B.Tech.
# 21    22  AP20110010024  CHORAPALLI VEERA VENKATA SATYANARAYANA  B.Tech.
# 20    21  AP20110010023        NARAHARI MANASA SIRI RAGHAVENDRA  B.Tech.
# 19    20  AP20110010022                       SATHVIKA VEGIRAJU  B.Tech.
# 24    25  AP20110010028                       THADIMARRI SAMEER  B.Tech.
#
#                               Branch  Batch Section  \
# ...

# %%
df1.to_excel("mydata.xlsx",index=False)

# %%
for i in df['Section']:
    df2=df[df['Section']==i]
    df2.to_excel("mydata.xlsx",sheet_name=i,index=False)

# %%
myval

# %%
import pandas as pd
df = pd.read_excel(r"D:\2020 students list.xlsx")

df.drop("S.No",inplace=True,axis=1)
df['Section']
# df['SECTION'].unique()
import os
os.makedirs("SectionsData",exist_ok=True)
for i in df['Section']:
    df1 = df[df['Section']==i]
#     df1.reset_index(drop = True,inplace=True)
    df1.to_excel(f"SectionsData/{i}.xlsx",index = False)
    # print(f"{i} sec data saved in SectionsData/{i}.xlsx")

# %%
import pandas as pd
df=pd.read_excel(r"D:\2020 students list.xlsx")

# %%
df.sort_values(by=['Section'])
for i in df['Section']:
    df1=df[df["Section"]==i]
    df1.to_excel("mydata.xlsx",sheet_name=i,index=False)

# %%
from pandas import Series, ExcelWriter

writer = ExcelWriter('output.xls')
for counter in range(n):
   sheet_name = 'Sheet%s' % counter
   series.to_frame(name = '').to_excel(writer, sheet_name=sheet_name)

writer.save()

# %%
df
# Out:
#      S.No   Register No.                           Student Name  Program  \
# 0       1  AP20110010001                     UPPULURI VAISHNAVI  B.Tech.
# 1       2  AP20110010002                     BANDI SAI HARSHITH  B.Tech.
# 2       3  AP20110010003  DAMARLA VENKATA VIGNESH HEMANTH KUMAR  B.Tech.
# 3       4  AP20110010004            KANULLA VENKATA SATISH BABU  B.Tech.
# 4       5  AP20110010005                        YEMINENI RAJESH  B.Tech.
# ..    ...            ...                                    ...      ...
# 730   731  AP20110010832                         METTU SABARISH  B.Tech.
# 731   732  AP20110010833                    MORAMPUDI TAATHVIKA  B.Tech.
# 732   733  AP20110010834                     KOTLA NAVEEN REDDY  B.Tech.
# 733   734  AP20110010835                        NABIN KUMAR SAH  B.Tech.
# 734   735  AP20110010836                      GORIPARTHI DEEPAK  B.Tech.
#
#                                Branch  Batch Section  \
# ...

# %%
import pandas as pd
df=pd.read_excel(r"D:\2020 students list.xlsx")
df["Section"].unique()
df.keys()
# Out:
# Index(['S.No', 'Register No.', 'Student Name', 'Program', 'Branch', 'Batch',
#        'Section', 'Email', 'Copy of Id card', 'Submitted TC',
#        'Submitted Migration', 'Signature of the student'],
#       dtype='object')

# %%
df.drop(['Copy of Id card'],['Submitted Migration'])
# Out:
# C:\Users\SRMAPCSELAB2022-241\AppData\Local\Temp\ipykernel_31768\902182434.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(['Copy of Id card'],['Submitted Migration'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.drop(['Copy of Id card'],['Submitted Migration'])
#
# File D:\menv\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import os
os.makedirs("Sec",exist_ok=True)

# %%
with pd.ExcelWriter("Sec/mydata.xlsx",engine='xlsxwriter') as writer:
    for i in df['Section']:
        df1=df[df["Section"]==i]

        df1.to_excel(writer, sheet_name=f"Sec_{i}", index=False)
writer.save()
# Out:
# C:\Users\SRMAPCSELAB2022-241\AppData\Local\Temp\ipykernel_31768\3997427930.py:6: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# D:\menv\Lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
# !pip install xlsxwriter
# Out:
# ...
#      ---------------------------------------- 0.0/152.7 kB ? eta -:--:--
#      ------------------ -------------------- 71.7/152.7 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 152.7/152.7 kB 1.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import the python pandas package
import pandas as pd

# create data_frame1 by creating a dictionary
# in which values are stored as list
data_frame1 = pd.DataFrame({'Fruits': ['Appple', 'Banana', 'Mango',
									'Dragon Fruit', 'Musk melon', 'grapes'],
							'Sales in kg': [20, 30, 15, 10, 50, 40]})

# create data_frame2 by creating a dictionary
# in which values are stored as list
data_frame2 = pd.DataFrame({'Vegetables': ['tomato', 'Onion', 'ladies finger',
										'beans', 'bedroot', 'carrot'],
							'Sales in kg': [200, 310, 115, 110, 55, 45]})

# create data_frame3 by creating a dictionary
# in which values are stored as list
data_frame3 = pd.DataFrame({'Baked Items': ['Cakes', 'biscuits', 'muffins',
											'Rusk', 'puffs', 'cupcakes'],
							'Sales in kg': [120, 130, 159, 310, 150, 140]})

print(data_frame1)
print(data_frame2)
print(data_frame3)

# create a excel writer object
with pd.ExcelWriter("filename.xlsx") as writer:

	# use to_excel function and specify the sheet_name and index
	# to store the dataframe in specified sheet
	data_frame1.to_excel(writer, sheet_name="Fruits", index=False)
	data_frame2.to_excel(writer, sheet_name="Vegetables", index=False)
	data_frame3.to_excel(writer, sheet_name="Baked Items", index=False)
# Out:
#          Fruits  Sales in kg
# 0        Appple           20
# 1        Banana           30
# 2         Mango           15
# 3  Dragon Fruit           10
# 4    Musk melon           50
# 5        grapes           40
#       Vegetables  Sales in kg
# 0         tomato          200
# 1          Onion          310
# 2  ladies finger          115
# 3          beans          110
# 4        bedroot           55
# 5         carrot           45
#   Baked Items  Sales in kg
# 0       Cakes          120
# 1    biscuits          130
# 2     muffins          159
# 3        Rusk          310
# 4       puffs          150
# 5    cupcakes          140

# %%
data_frame1
# Out:
#          Fruits  Sales in kg
# 0        Appple           20
# 1        Banana           30
# 2         Mango           15
# 3  Dragon Fruit           10
# 4    Musk melon           50
# 5        grapes           40

# %%
df1
# Out:
#      S.No   Register No.                               Student Name  Program  \
# 679   680  AP20110010775                 MARTHALA MANI KESAVA REDDY  B.Tech.
# 680   681  AP20110010776                    ANKALLA GEORGE WITFIELD  B.Tech.
# 681   682  AP20110010779                             BURRI SRINIVAS  B.Tech.
# 682   683  AP20110010780                   PARISAPOGU SARAT SIVARAM  B.Tech.
# 683   684  AP20110010781                      TIPIRISETTY DHANA SRI  B.Tech.
# 684   685  AP20110010782                   SITA CHANDRA MALLIPAMULA  B.Tech.
# 685   686  AP20110010783                      MASUNA JAYASWI PRASAD  B.Tech.
# 686   687  AP20110010784                         SRIRAM VISHNUPRIYA  B.Tech.
# 687   688  AP20110010785                         BODDUPALLI BHARGAV  B.Tech.
# 688   689  AP20110010786             PEDDIBOYINA SATYA KANAKA DURGA  B.Tech.
# 689   690  AP20110010787                      VENKATA SAI CHAITANYA  B.Tech.
# ...

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://vegetablemarketprice.com/market/andhraPradesh/today"
req=requests.get(url)

# %%
print(req)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.content,"html.parser")

# %%
images=[]
for image in soup.findAll("div",{"class":"vegetableImageDiv"}):
    images.append("https://vegetablemarketprice.com"+image.get("image-src-file"))

# %%
veg_images=[]
for i in range(len(images)):
    veg_images.append(images[i].replace("64","256"))
df=pd.read_html("https://vegetablemarketprice.com/market/andhraPradesh/today")

# %%
df=df[0]

# %%
# Out:
#     Unnamed: 0              Vegetable Wholesale Price Retail Price  \
# 0          NaN              Onion Big             ₹19     ₹22 - 24
# 1          NaN            Onion Small             ₹55     ₹63 - 70
# 2          NaN                 Tomato             ₹18     ₹21 - 23
# 3          NaN           Green Chilli             ₹46     ₹53 - 58
# 4          NaN               Beetroot             ₹38     ₹44 - 48
# 5          NaN                 Potato             ₹22     ₹25 - 28
# 6          NaN  Raw Banana (Plantain)              ₹9     ₹10 - 11
# 7          NaN        Amaranth Leaves             ₹11     ₹13 - 14
# 8          NaN                   Amla             ₹70     ₹81 - 89
# 9          NaN              Ash gourd             ₹18     ₹21 - 23
# 10         NaN              Baby Corn             ₹57     ₹66 - 72
# 11         NaN          Banana Flower             ₹22     ₹25 - 28
# 12         NaN               Capsicum             ₹43     ₹49 - 55
# ...

# %%
df['Unnamed: 0']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df['Unnamed: 0']
#
# TypeError: list indices must be integers or slices, not str
